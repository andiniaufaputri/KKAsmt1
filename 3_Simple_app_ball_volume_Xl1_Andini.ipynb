# %% [markdown]
# <a href="https://colab.research.google.com/github/andiniaufaputri/KKAsmt1/blob/main/3_Simple_app_ball_volume_Xl1_Andini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Andini Aufa Putri
#
# Kelas : Xl.1
#
# No absen : 06
#
# Nama Kelompok : Taylor Swift

# %% [markdown]
# #Aplikasi Sederhana menghitung Volume Bola

# %%
r = float(input("Masukkan jari-jari bola (dalam satuan cm): "))
pi = 3.14
volume = (4/3) * pi * r**3

print(f"Volume bola dengan jari-jari {r} cm adalah {volume:.2f
                                                    } cm³")
# Out:
# Masukkan jari-jari bola (dalam satuan cm): 5
# Volume bola dengan jari-jari 5.0 cm adalah 523.33 cm³
